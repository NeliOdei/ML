# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'C:\Users\rocki\Downloads\Tomato.csv', header=0, index_col=0, parse_dates=True,
squeeze=True)
df = df.replace(',', '.', regex=True)

# %% [markdown]
# ## Первичная обработка данных и визуализация

# %% [markdown]
# ### Первичный анализ

# %% [markdown]
# Выведем первые 5 строк датасета:

# %%
df.head()
# Out:
#            Unit  Minimum  Maximum  Average  Market
# Date
# 2013-06-16   Kg       26       32     29.0  Tomato
# 2013-06-17   Kg       20       25     22.5  Tomato
# 2013-06-18   Kg       22       26     24.0  Tomato
# 2013-06-19   Kg       24       28     26.0  Tomato
# 2013-06-20   Kg       22       26     24.0  Tomato

# %% [markdown]
# Определим размер датасета:

# %%
df.shape
# Out:
# (2741, 5)

# %% [markdown]
# Определим типы данных:

# %%
df.dtypes
# Out:
# Unit        object
# Minimum      int64
# Maximum      int64
# Average    float64
# Market      object
# dtype: object

# %% [markdown]
# ### Обработка данных

# %%
def draw_missing(df):
    total = df.isnull().sum().sort_values(ascending=False)
    percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)*100
    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    return missing_data

# %%
draw_missing(df).round(1)
# Out:
#          Total  Percent
# Unit         0      0.0
# Minimum      0      0.0
# Maximum      0      0.0
# Average      0      0.0
# Market       0      0.0

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler, Normalizer

# %%
sc1 = MinMaxScaler()
df['Average'] = sc1.fit_transform(df[['Average']])
df['Maximum'] = sc1.fit_transform(df[['Maximum']])
df['Minimum'] = sc1.fit_transform(df[['Minimum']])
df
# Out:
#            Unit   Minimum   Maximum   Average  Market
# Date
# 2013-06-16   Kg  0.168224  0.185185  0.176744  Tomato
# 2013-06-17   Kg  0.112150  0.120370  0.116279  Tomato
# 2013-06-18   Kg  0.130841  0.129630  0.130233  Tomato
# 2013-06-19   Kg  0.149533  0.148148  0.148837  Tomato
# 2013-06-20   Kg  0.130841  0.129630  0.130233  Tomato
# ...         ...       ...       ...       ...     ...
# 2021-05-09   Kg  0.018692  0.027778  0.023256  Tomato
# 2021-05-10   Kg  0.018692  0.027778  0.023256  Tomato
# 2021-05-11   Kg  0.018692  0.027778  0.023256  Tomato
# 2021-05-12   Kg  0.205607  0.212963  0.209302  Tomato
# 2021-05-13   Kg  0.252336  0.259259  0.255814  Tomato
#
# [2741 rows x 5 columns]

# %%
df
# Out:
#            Unit   Minimum   Maximum   Average  Market
# Date
# 2013-06-16   Kg  0.168224  0.185185  0.176744  Tomato
# 2013-06-17   Kg  0.112150  0.120370  0.116279  Tomato
# 2013-06-18   Kg  0.130841  0.129630  0.130233  Tomato
# 2013-06-19   Kg  0.149533  0.148148  0.148837  Tomato
# 2013-06-20   Kg  0.130841  0.129630  0.130233  Tomato
# ...         ...       ...       ...       ...     ...
# 2021-05-09   Kg  0.018692  0.027778  0.023256  Tomato
# 2021-05-10   Kg  0.018692  0.027778  0.023256  Tomato
# 2021-05-11   Kg  0.018692  0.027778  0.023256  Tomato
# 2021-05-12   Kg  0.205607  0.212963  0.209302  Tomato
# 2021-05-13   Kg  0.252336  0.259259  0.255814  Tomato
#
# [2741 rows x 5 columns]

# %%
df = df.drop(columns=['Unit'], axis=1)
df = df.drop(columns=['Minimum'], axis=1)
df = df.drop(columns=['Maximum'], axis=1)
df = df.drop(columns=['Market'], axis=1)

# %% [markdown]
# ### Основные статистические характеристки

# %%
df.describe()
# Out:
#            Average
# count  2741.000000
# mean      0.262191
# std       0.157869
# min       0.000000
# 25%       0.139535
# 50%       0.232558
# 75%       0.348837
# max       1.000000

# %% [markdown]
# ### Визуализация исходного временного ряда

# %%
fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(10,5))
fig.suptitle('Временной ряд в виде графика')
df.plot(ax=ax, legend=False)
pyplot.show()

# %%
fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(10,5))
fig.suptitle('Первые 30 точек ряда')
df[:30].plot(ax=ax, legend=False)
pyplot.show()

# %%
fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(10,5))
fig.suptitle('Гистограмма')
df.hist(ax=ax, legend=False)
pyplot.show()

# %%
fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(10,5))
fig.suptitle('Плотность вероятности распределения данных')
df.plot(ax=ax, kind='kde', legend=False)
pyplot.show()

# %%
for i in range(1, 5):
    fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(5,4))
    fig.suptitle(f'Лаг порядка {i}')
    pd.plotting.lag_plot(df, lag=i, ax=ax)
    pyplot.show()

# %% [markdown]
# Наблюдается достаточно сильная положительная корреляция.

# %% [markdown]
# Автокорреляционная диаграмма:

# %%
fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(10,5))
fig.suptitle('Автокорреляционная диаграмма')
pd.plotting.autocorrelation_plot(df, ax=ax)
pyplot.show()

# %% [markdown]
# Автокорреляционная функция:

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(df, lags=30)
plt.tight_layout()

# %% [markdown]
# Частичная автокорреляционная функция:

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(df, lags=30)
plt.tight_layout()

# %% [markdown]
# Временной ряд со скользящими средними:

# %%
df2 = df.copy()

# %%
df2['SMA_10'] = df2['Average'].rolling(10, min_periods=1).mean()
df2['SMA_20'] = df2['Average'].rolling(20, min_periods=1).mean()

# %%
fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(10,5))
fig.suptitle('Временной ряд со скользящими средними')
df2[:100].plot(ax=ax, legend=True)
pyplot.show()

# %% [markdown]
# ## Прогнозирование временного ряда с использованием авторегрессионного метода

# %% [markdown]
# Будем использовать авторегриссионный метод ARIMA:

# %%
from statsmodels.tsa.arima.model import ARIMA

# %% [markdown]
# Разделение выборки на обучающую и тестовую

# %%
xnum = list(range(df2.shape[0]))
Y = df2['Average'].values
train_size = int(len(Y) * 0.7)
xnum_train, xnum_test = xnum[0:train_size], xnum[train_size:]
train, test = Y[0:train_size], Y[train_size:]
history_arima = [x for x in train]

# %% [markdown]
# ## Прогноз ARIMA

# %%
arima_order = (6, 1, 0)
predictions_arima = list()
for t in range(len(test)):
    model_arima = ARIMA(history_arima, order=arima_order)
    model_arima_fit = model_arima.fit()
    yhat_arima = model_arima_fit.forecast()[0]
    predictions_arima.append(yhat_arima)
    history_arima.append(test[t])

# %%
df2['predictions_ARIMA'] = (train_size * [np.NAN]) + list(predictions_arima)

# %%
fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(20,10))
fig.suptitle('Предсказания временного ряда')
df2.plot(ax=ax, legend=True)
pyplot.show()

# %%
fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(20,10))
fig.suptitle('Предсказания временного ряда (тестовая выборка)')
df2[train_size:].plot(ax=ax, legend=True)
pyplot.show()

# %% [markdown]
# Предсказания ARIMA точны, близки к исходному, далеки от среднего скользящего.

# %% [markdown]
# ## Метрики

# %% [markdown]
# MAE и MSE:

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mean_squared_error(test, predictions_arima, squared=False)
# Out:
# 0.05888270415854181

# %%
mean_absolute_error(test, predictions_arima)
# Out:
# 0.03902739149994073

# %% [markdown]
# ## Прогнозирование временного ряда с использованием метода символьной регрессии

# %% [markdown]
# Будем использовать библиотеку gplearn:

# %%
# pip install gplearn
# Out:
# Collecting gplearn
#   Downloading gplearn-0.4.2-py3-none-any.whl (25 kB)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\rocki\anaconda3\lib\site-packages (from gplearn) (1.1.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\rocki\anaconda3\lib\site-packages (from gplearn) (1.0.2)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\rocki\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->gplearn) (1.21.5)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\rocki\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->gplearn) (1.9.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\rocki\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->gplearn) (2.2.0)
# Installing collected packages: gplearn
# Successfully installed gplearn-0.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from gplearn.genetic import SymbolicRegressor

# %%
function_set = ['add', 'sub', 'mul', 'div', 'sin']
est_gp = SymbolicRegressor(population_size=500, metric='mse',
                               generations=200, stopping_criteria=0.01,
                               init_depth=(4, 10), verbose=1, function_set=function_set,
                               const_range=(-10, 10), random_state=0)

# %%
est_gp.fit(np.array(xnum_train).reshape(-1, 1), train.reshape(-1, 1))
# Out:
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0   263.65      1.11883e+73      129        0.0603976              N/A     10.16m
#    1    69.30      1.46958e+18        3        0.0270681              N/A      2.67m
#    2    16.31      2.09298e+13       16        0.0219739              N/A      1.62m
#    3    13.36      7.79838e+10       13        0.0214411              N/A      1.29m
#    4     2.88           147389       12        0.0213719              N/A      1.20m
#    5     1.99      5.40616e+09        2        0.0269164              N/A      1.40m
#    6     2.05          4927.87        2        0.0269164              N/A      1.13m
#    7     1.99           176890        2        0.0269164              N/A      1.23m
#    8     1.99          9803.64        2        0.0269164              N/A      1.22m
#    9     2.04           771674        2        0.0269164              N/A      1.73m
#   10     2.42      1.28243e+08        2        0.0269164              N/A      1.22m
#   11     2.24          40223.2        2        0.0216898              N/A     54.86s
#   12     2.05           1993.2        3        0.0215426              N/A      1.38m
#   13     2.01      5.41339e+09        3        0.0215426              N/A      1.14m
#   14     1.14      5.40617e+09        3        0.0215426              N/A      1.02m
#   15     1.04      1.03315e+07        1        0.0218707              N/A     55.76s
#   16     1.07          2454.37        1        0.0218707              N/A      1.05m
#   17     1.09          24567.6        1        0.0218707              N/A     58.99s
#   18     1.12          85848.4        1        0.0218707              N/A      1.03m
#   19     1.02           135.61        1        0.0218707              N/A      1.24m
#   20     1.19      5.40616e+09        1        0.0218707              N/A     52.38s
#   21     1.20      1.47211e+09        1        0.0218707              N/A      1.12m
#   22     1.04      2.16153e+10        1        0.0218707              N/A     59.01s
#   23     1.09      8.10605e+09        1        0.0218707              N/A     54.60s
#   24     1.02          67491.3        1        0.0218707              N/A     57.28s
#   25     1.07           313015        1        0.0218707              N/A     59.74s
#   26     1.03            12674        1        0.0218707              N/A     51.25s
#   27     1.06          68149.8        1        0.0218707              N/A      1.23m
#   28     1.04          2449.66        1        0.0218707              N/A      1.07m
#   29     1.02          2449.61        1        0.0218707              N/A     51.99s
#  173     1.14      2.96466e+18        1        0.0218707              N/A      9.54s
#  174     1.10       1.0945e+10        1        0.0218707              N/A     11.40s
#  175     1.08          2815.67        1        0.0218707              N/A      9.66s
#  176     1.03      5.43614e+09        1        0.0218707              N/A      9.40s
#  177     1.07           313293        1        0.0218707              N/A      8.22s
#  178     1.02          12232.4        1        0.0218707              N/A      7.53s
#  179     1.10      1.48848e+10        1        0.0218707              N/A      8.57s
#  180     1.06           400432        1        0.0218707              N/A      6.47s
#  181     1.07          17180.6        1        0.0218707              N/A      6.81s
#  182     1.10      1.38657e+11        1        0.0218707              N/A      7.35s
#  183     1.05           367777        1        0.0218707              N/A      6.11s
#  184     1.03           232903        1        0.0218707              N/A      6.67s
#  185     1.01      5.40615e+09        1        0.0218707              N/A      4.77s
#  186     1.02          2449.62        1        0.0218707              N/A      4.86s
#  187     1.11          2422.43        1        0.0218707              N/A      4.27s
#  188     1.08      1.11727e+16        1        0.0218707              N/A      4.58s
#  189     1.00          55389.4        1        0.0218707              N/A      3.88s
#  190     1.05          29942.4        1        0.0218707              N/A      3.71s
#  191     1.05      1.08125e+10        1        0.0218707              N/A      3.29s
#  192     1.24      1.09609e+10        1        0.0218707              N/A      2.53s
#  193     1.05           220362        1        0.0218707              N/A      2.79s
#  194     1.02          2468.79        1        0.0218707              N/A      1.72s
#  195     1.31       1.9805e+39        1        0.0218707              N/A      1.77s
#  196     1.21          8781.93        1        0.0218707              N/A      1.50s
#  197     1.11      1.68615e+14        1        0.0218707              N/A      0.94s
#  198     1.03          9797.99        1        0.0218707              N/A      0.45s
#  199     1.03           550.33        1        0.0218707              N/A      0.00s
# SymbolicRegressor(const_range=(-10, 10),
#                   function_set=['add', 'sub', 'mul', 'div', 'sin'],
#                   generations=200, init_depth=(4, 10), metric='mse',
#                   population_size=500, random_state=0, stopping_criteria=0.01,
#                   verbose=1)

# %%
y_gp = est_gp.predict(np.array(xnum_test).reshape(-1, 1))
y_gp[:10]
# Out:
# array([0.28311543, 0.28311543, 0.28311543, 0.28311543, 0.28311543,
#        0.28311543, 0.28311543, 0.28311543, 0.28311543, 0.28311543])

# %%
df2['predictions_GPLEARN'] = (train_size * [np.NAN]) + list(y_gp)

# %% [markdown]
# ## Визуализация

# %% [markdown]
# Построим дерево по символьной регрессии:

# %%
import graphviz
import pydotplus
from sklearn.tree import export_graphviz

# %%
dot_data = est_gp._program.export_graphviz()
graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# Построим график по тестовой выборке:

# %%
fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(20,10))
fig.suptitle('Предсказания временного ряда (тестовая выборка)')
df2[train_size:].plot(ax=ax, legend=True)
pyplot.show()

# %% [markdown]
# ## Метрики

# %% [markdown]
# MAE и MSE:

# %%
mean_squared_error(test, y_gp, squared=False)
# Out:
# 0.18292986185934695

# %%
mean_absolute_error(test, y_gp)
# Out:
# 0.1466313581824661
