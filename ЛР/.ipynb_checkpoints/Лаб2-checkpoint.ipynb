# %%
import sklearn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import math as mth
import matplotlib.patches as patches
from scipy import stats as st
plt.rcParams.update({'figure.max_open_warning': 0})
import plotly.graph_objects as go
import plotly.express as px
from sklearn.preprocessing import StandardScaler
pd.options.mode.chained_assignment = None

from pandas import plotting
from scipy import stats
plt.style.use("ggplot")
#import warnings
#warnings.filterwarnings("ignore")


# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os

# %%
df = pd.read_csv(r"C:\Users\rocki\Documents\2 сем\ТМО\qs-world-university-rankings-2017-to-2022-V2.csv")
df = df.replace(',', '.', regex=True)

# %%
df
# Out:
#                                         university  year rank_display  score  \
# 0     Massachusetts Institute of Technology (MIT)   2017            1  100.0
# 1                              Stanford University  2017            2   98.7
# 2                               Harvard University  2017            3   98.3
# 3                          University of Cambridge  2017            4   97.2
# 4     California Institute of Technology (Caltech)  2017            5   96.9
# ...                                            ...   ...          ...    ...
# 6477                           Université de Tunis  2022         1201    NaN
# 6478                  Université de Tunis El Manar  2022         1201    NaN
# 6479                            Yarmouk University  2022         1201    NaN
# 6480                   Yildiz Technical University  2022         1201    NaN
# 6481                            Zagazig University  2022         1201    NaN
#
#                                                    link         country  \
# 0     https://www.topuniversities.com/universities/m...   United States
# 1     https://www.topuniversities.com/universities/s...   United States
# 2     https://www.topuniversities.com/universities/h...   United States
# 3     https://www.topuniversities.com/universities/u...  United Kingdom
# 4     https://www.topuniversities.com/universities/c...   United States
# ...                                                 ...             ...
# 6477  https://www.topuniversities.com/universities/u...         Tunisia
# 6478  https://www.topuniversities.com/universities/u...         Tunisia
# 6479  https://www.topuniversities.com/universities/y...          Jordan
# 6480  https://www.topuniversities.com/universities/y...          Turkey
# 6481  https://www.topuniversities.com/universities/z...           Egypt
#
#            city         region  \
# 0     Cambridge  North America
# 1      Stanford  North America
# 2     Cambridge  North America
# 3     Cambridge         Europe
# 4      Pasadena  North America
# ...         ...            ...
# 6477      Tunis         Africa
# 6478      Tunis         Africa
# 6479      Irbid           Asia
# 6480   Istanbul           Asia
# 6481    Zagazig         Africa
#
#                                                    logo     type  \
# 0     https://www.topuniversities.com/sites/default/...  Private
# 1     https://www.topuniversities.com/sites/default/...  Private
# 2     https://www.topuniversities.com/sites/default/...  Private
# 3     https://www.topuniversities.com/sites/default/...   Public
# 4     https://www.topuniversities.com/sites/default/...  Private
# ...                                                 ...      ...
# 6477  https://www.topuniversities.com/sites/default/...   Public
# 6478  https://www.topuniversities.com/sites/default/...   Public
# 6479  https://www.topuniversities.com/sites/default/...   Public
# 6480  https://www.topuniversities.com/sites/default/...   Public
# 6481  https://www.topuniversities.com/sites/default/...   Public
#
#      research_output  student_faculty_ratio international_students size  \
# 0          Very High                    4.0                  3.730    M
# 1          Very High                    3.0                  3.879    L
# 2          Very High                    5.0                  5.877    L
# 3          Very high                    4.0                  7.925    L
# 4          Very High                    2.0                    692    S
# ...              ...                    ...                    ...  ...
# 6477            High                   17.0                     57    L
# 6478       Very High                    8.0                    585    L
# 6479          Medium                   31.0                  2.826   XL
# 6480            High                   20.0                  2.394   XL
# 6481            High                   26.0                  2.300   XL
#
#      faculty_count
# 0            3.065
# 1            4.725
# 2            4.646
# 3            5.800
# 4              968
# ...            ...
# 6477         1.174
# 6478         3.504
# 6479         1.113
# 6480         1.688
# 6481         5.871
#
# [6482 rows x 15 columns]

# %%
df = df[(df.year == 2019)]

# %%
df
# Out:
#                                         university  year rank_display  score  \
# 1910  Massachusetts Institute of Technology (MIT)   2019            1  100.0
# 1911                           Stanford University  2019            2   98.6
# 1912                            Harvard University  2019            3   98.5
# 1913  California Institute of Technology (Caltech)  2019            4   97.2
# 1914                          University of Oxford  2019            5   96.8
# ...                                            ...   ...          ...    ...
# 2923  Université de Technologie de Compiègne (UTC)  2019          NaN    NaN
# 2924       University of California. San Francisco  2019          NaN    NaN
# 2925   Prague University of Economics and Business  2019          NaN    NaN
# 2926                 Weizmann Institute of Science  2019          NaN    NaN
# 2927     WHU - Otto Beisheim School of Management   2019          NaN   69.6
#
#                                                    link         country  \
# 1910  https://www.topuniversities.com/universities/m...   United States
# 1911  https://www.topuniversities.com/universities/s...   United States
# 1912  https://www.topuniversities.com/universities/h...   United States
# 1913  https://www.topuniversities.com/universities/c...   United States
# 1914  https://www.topuniversities.com/universities/u...  United Kingdom
# ...                                                 ...             ...
# 2923  https://www.topuniversities.com/universities/u...          France
# 2924  https://www.topuniversities.com/universities/u...   United States
# 2925  https://www.topuniversities.com/universities/p...  Czech Republic
# 2926  https://www.topuniversities.com/universities/w...          Israel
# 2927  https://www.topuniversities.com/universities/w...         Germany
#
#                city         region  \
# 1910      Cambridge  North America
# 1911       Stanford  North America
# 1912      Cambridge  North America
# 1913       Pasadena  North America
# 1914         Oxford         Europe
# ...             ...            ...
# 2923      Compiègne         Europe
# 2924  San Francisco  North America
# 2925         Prague         Europe
# 2926        Rehovot           Asia
# 2927      Vallendar         Europe
#
#                                                    logo     type  \
# 1910  https://www.topuniversities.com/sites/default/...  Private
# 1911  https://www.topuniversities.com/sites/default/...  Private
# 1912  https://www.topuniversities.com/sites/default/...  Private
# 1913  https://www.topuniversities.com/sites/default/...  Private
# 1914  https://www.topuniversities.com/sites/default/...   Public
# ...                                                 ...      ...
# 2923  https://www.topuniversities.com/sites/default/...   Public
# 2924  https://www.topuniversities.com/sites/default/...   Public
# 2925  https://www.topuniversities.com/sites/default/...   Public
# 2926  https://www.topuniversities.com/sites/default/...   Public
# 2927  https://www.topuniversities.com/sites/default/...  Private
#
#      research_output  student_faculty_ratio international_students size  \
# 1910       Very High                    4.0                  3.730    M
# 1911       Very High                    3.0                  3.879    L
# 1912       Very High                    5.0                  5.877    L
# 1913       Very High                    2.0                    692    S
# 1914       Very High                    3.0                  8.442    L
# ...              ...                    ...                    ...  ...
# 2923       Very High                    NaN                    NaN    S
# 2924       Very High                    1.0                    125    S
# 2925       Very High                   27.0                  3.322    L
# 2926       Very High                    NaN                    NaN    S
# 2927       Very High                    NaN                    NaN    S
#
#      faculty_count
# 1910         3.065
# 1911         4.725
# 1912         4.646
# 1913           968
# 1914         6.708
# ...            ...
# 2923           NaN
# 2924         4.482
# 2925           468
# 2926           NaN
# 2927           NaN
#
# [1018 rows x 15 columns]

# %% [markdown]
# Заметим, что данные содержащиеся в link, logo и university - уникальные и бесполезны для анализа, поэтому удалим их из датафрейма

# %%
df.drop(['link'],axis=1,inplace=True)
df.drop(['logo'],axis=1,inplace=True)
df.drop(['university'],axis=1,inplace=True)
df.drop(['year'],axis=1,inplace=True)

# %%
df["student_faculty_ratio"] = df["student_faculty_ratio"].astype("float64")
df["international_students"] = df["international_students"].astype("float64")
df["faculty_count"] = df["faculty_count"].astype("float64")

# %%
def draw_missing(df):
    total = df.isnull().sum().sort_values(ascending=False)
    percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)*100
    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    return missing_data

# %%
draw_missing(df).round(1)
# Out:
#                         Total  Percent
# score                     513     50.4
# international_students     26      2.6
# city                       25      2.5
# rank_display               20      2.0
# student_faculty_ratio      14      1.4
# faculty_count              14      1.4
# type                        2      0.2
# country                     0      0.0
# region                      0      0.0
# research_output             0      0.0
# size                        0      0.0

# %%
df.dtypes
# Out:
# rank_display               object
# score                     float64
# country                    object
# city                       object
# region                     object
# type                       object
# research_output            object
# student_faculty_ratio     float64
# international_students    float64
# size                       object
# faculty_count             float64
# dtype: object

# %%
df
# Out:
#      rank_display  score         country           city         region  \
# 1910            1  100.0   United States      Cambridge  North America
# 1911            2   98.6   United States       Stanford  North America
# 1912            3   98.5   United States      Cambridge  North America
# 1913            4   97.2   United States       Pasadena  North America
# 1914            5   96.8  United Kingdom         Oxford         Europe
# ...           ...    ...             ...            ...            ...
# 2923          NaN    NaN          France      Compiègne         Europe
# 2924          NaN    NaN   United States  San Francisco  North America
# 2925          NaN    NaN  Czech Republic         Prague         Europe
# 2926          NaN    NaN          Israel        Rehovot           Asia
# 2927          NaN   69.6         Germany      Vallendar         Europe
#
#          type research_output  student_faculty_ratio  international_students  \
# 1910  Private       Very High                    4.0                   3.730
# 1911  Private       Very High                    3.0                   3.879
# 1912  Private       Very High                    5.0                   5.877
# 1913  Private       Very High                    2.0                 692.000
# 1914   Public       Very High                    3.0                   8.442
# ...       ...             ...                    ...                     ...
# 2923   Public       Very High                    NaN                     NaN
# 2924   Public       Very High                    1.0                 125.000
# 2925   Public       Very High                   27.0                   3.322
# 2926   Public       Very High                    NaN                     NaN
# 2927  Private       Very High                    NaN                     NaN
#
#      size  faculty_count
# 1910    M          3.065
# 1911    L          4.725
# 1912    L          4.646
# 1913    S        968.000
# 1914    L          6.708
# ...   ...            ...
# 2923    S            NaN
# 2924    S          4.482
# 2925    L        468.000
# 2926    S            NaN
# 2927    S            NaN
#
# [1018 rows x 11 columns]

# %%
from sklearn.impute import SimpleImputer
imp2 = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
df[['type']] = imp2.fit_transform(df[['type']])

# %%
draw_missing(df).round(1)
# Out:
#                         Total  Percent
# score                     513     50.4
# international_students     26      2.6
# city                       25      2.5
# rank_display               20      2.0
# student_faculty_ratio      14      1.4
# faculty_count              14      1.4
# country                     0      0.0
# region                      0      0.0
# type                        0      0.0
# research_output             0      0.0
# size                        0      0.0

# %% [markdown]
# ## Заполнение пропусков категориальных признаков (заполнение константой)
# Заполним столбец City

# %%
imp3 = SimpleImputer(missing_values=np.nan, strategy='constant', fill_value='Unknown')
df[['city']] = imp3.fit_transform(df[['city']])

# %%
draw_missing(df).round(1)
# Out:
#                         Total  Percent
# score                     513     50.4
# international_students     26      2.6
# rank_display               20      2.0
# student_faculty_ratio      14      1.4
# faculty_count              14      1.4
# country                     0      0.0
# city                        0      0.0
# region                      0      0.0
# type                        0      0.0
# research_output             0      0.0
# size                        0      0.0

# %% [markdown]
# ## Импьютация целочисленных значений
# Используем колонку International students

# %%
total_count = df.shape[0]
num_cols = []
for col in df.columns:
    # Количество пустых значений 
    temp_null_count = df[df[col].isnull()].shape[0]
    dt = str(df[col].dtype)
    if temp_null_count>0 and (dt=='float64' or dt=='int64'):
        num_cols.append(col)
        temp_perc = round((temp_null_count / total_count) * 100.0, 2)
        print('Колонка {}. Тип данных {}. Количество пустых значений {}, {}%.'.format(col, dt, temp_null_count, temp_perc))
# Out:
# Колонка rank_display. Тип данных float64. Количество пустых значений 20, 1.96%.
# Колонка score. Тип данных float64. Количество пустых значений 513, 50.39%.
# Колонка student_faculty_ratio. Тип данных float64. Количество пустых значений 14, 1.38%.
# Колонка international_students. Тип данных float64. Количество пустых значений 26, 2.55%.
# Колонка faculty_count. Тип данных float64. Количество пустых значений 14, 1.38%.

# %%
data_num = df[num_cols]
data_num
# Out:
#       rank_display  score  student_faculty_ratio  international_students  \
# 1910           1.0  100.0                    4.0                   3.730
# 1911           2.0   98.6                    3.0                   3.879
# 1912           3.0   98.5                    5.0                   5.877
# 1913           4.0   97.2                    2.0                 692.000
# 1914           5.0   96.8                    3.0                   8.442
# ...            ...    ...                    ...                     ...
# 2923           NaN    NaN                    NaN                     NaN
# 2924           NaN    NaN                    1.0                 125.000
# 2925           NaN    NaN                   27.0                   3.322
# 2926           NaN    NaN                    NaN                     NaN
# 2927           NaN   69.6                    NaN                     NaN
#
#       faculty_count
# 1910          3.065
# 1911          4.725
# 1912          4.646
# 1913        968.000
# 1914          6.708
# ...             ...
# 2923            NaN
# 2924          4.482
# 2925        468.000
# 2926            NaN
# 2927            NaN
#
# [1018 rows x 5 columns]

# %%
# Гистограмма по признакам
for col in data_num:
    plt.hist(df[col], 50)
    plt.xlabel(col)
    plt.show()

# %% [markdown]
# Проанализировав гистограмму придем к выводу, что лучше всего будет заполнить пропуски наиболее часто встречающимся значением.

# %%
IntStud = data_num[['international_students']]
IntStud.head()
# Out:
#       international_students
# 1910                   3.730
# 1911                   3.879
# 1912                   5.877
# 1913                 692.000
# 1914                   8.442

# %%
from sklearn.impute import MissingIndicator
indicator = MissingIndicator()
mask_missing_values_only = indicator.fit_transform(IntStud)
mask_missing_values_only
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [ True],
#        [ True]])

# %%
strategies=['mean', 'median', 'most_frequent']

# %%
def test_num_impute(strategy_param):
    imp_num = SimpleImputer(strategy=strategy_param)
    data_num_imp = imp_num.fit_transform(IntStud)
    return data_num_imp[mask_missing_values_only]

# %%
strategies[0], test_num_impute(strategies[0])
# Out:
# ('mean',
#  array([140.13480343, 140.13480343, 140.13480343, 140.13480343,
#         140.13480343, 140.13480343, 140.13480343, 140.13480343,
#         140.13480343, 140.13480343, 140.13480343, 140.13480343,
#         140.13480343, 140.13480343, 140.13480343, 140.13480343,
#         140.13480343, 140.13480343, 140.13480343, 140.13480343,
#         140.13480343, 140.13480343, 140.13480343, 140.13480343,
#         140.13480343, 140.13480343]))

# %%
strategies[1], test_num_impute(strategies[1])
# Out:
# ('median',
#  array([5.035, 5.035, 5.035, 5.035, 5.035, 5.035, 5.035, 5.035, 5.035,
#         5.035, 5.035, 5.035, 5.035, 5.035, 5.035, 5.035, 5.035, 5.035,
#         5.035, 5.035, 5.035, 5.035, 5.035, 5.035, 5.035, 5.035]))

# %%
strategies[2], test_num_impute(strategies[2])
# Out:
# C:\Users\rocki\anaconda3\lib\site-packages\sklearn\impute\_base.py:49: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode = stats.mode(array)
# ('most_frequent',
#  array([1.29, 1.29, 1.29, 1.29, 1.29, 1.29, 1.29, 1.29, 1.29, 1.29, 1.29,
#         1.29, 1.29, 1.29, 1.29, 1.29, 1.29, 1.29, 1.29, 1.29, 1.29, 1.29,
#         1.29, 1.29, 1.29, 1.29]))

# %%
    temp_data = df[['international_students']]
    indicator = MissingIndicator()
    mask_missing_values_only = indicator.fit_transform(temp_data)
    imp_num = SimpleImputer(strategy=strategies[2])
    data_num_imp = imp_num.fit_transform(temp_data)
    filled_data = data_num_imp[mask_missing_values_only]
    df[['international_students']] = data_num_imp
# Out:
# C:\Users\rocki\anaconda3\lib\site-packages\sklearn\impute\_base.py:49: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode = stats.mode(array)

# %%
data_num_imp
# Out:
# array([[3.73 ],
#        [3.879],
#        [5.877],
#        ...,
#        [3.322],
#        [1.29 ],
#        [1.29 ]])

# %%
draw_missing(df).round(1)
# Out:
#                         Total  Percent
# score                     513     50.4
# rank_display               20      2.0
# student_faculty_ratio      14      1.4
# faculty_count              14      1.4
# country                     0      0.0
# city                        0      0.0
# region                      0      0.0
# type                        0      0.0
# research_output             0      0.0
# international_students      0      0.0
# size                        0      0.0

# %% [markdown]
# Во всех остальных столбцах кол-во пропусков не превышает 5% (за исключением столбца score), поэтому мы можем позволить себе удалить пропуски:

# %%
df = df.dropna (subset=[ 'faculty_count', 'student_faculty_ratio','rank_display'])

# %%
draw_missing(df).round(1)
# Out:
#                         Total  Percent
# score                     494     49.8
# rank_display                0      0.0
# country                     0      0.0
# city                        0      0.0
# region                      0      0.0
# type                        0      0.0
# research_output             0      0.0
# student_faculty_ratio       0      0.0
# international_students      0      0.0
# size                        0      0.0
# faculty_count               0      0.0

# %%
df
# Out:
#       rank_display  score         country       city         region     type  \
# 1910           1.0  100.0   United States  Cambridge  North America  Private
# 1911           2.0   98.6   United States   Stanford  North America  Private
# 1912           3.0   98.5   United States  Cambridge  North America  Private
# 1913           4.0   97.2   United States   Pasadena  North America  Private
# 1914           5.0   96.8  United Kingdom     Oxford         Europe   Public
# ...            ...    ...             ...        ...            ...      ...
# 2903         900.0    NaN          Russia  Voronezh          Europe   Public
# 2904         900.0    NaN       Lithuania     Kaunas         Europe   Public
# 2905         900.0    NaN         Romania  Timișoara         Europe   Public
# 2906         900.0    NaN          Poland   Wroclaw          Europe   Public
# 2907         900.0    NaN     South Korea  Gyeongsan           Asia  Private
#
#      research_output  student_faculty_ratio  international_students size  \
# 1910       Very High                    4.0                   3.730    M
# 1911       Very High                    3.0                   3.879    L
# 1912       Very High                    5.0                   5.877    L
# 1913       Very High                    2.0                 692.000    S
# 1914       Very High                    3.0                   8.442    L
# ...              ...                    ...                     ...  ...
# 2903            High                   12.0                   2.585    L
# 2904       Very High                   11.0                 994.000    M
# 2905            High                   21.0                 799.000    L
# 2906       Very High                   11.0                   1.159    L
# 2907            High                   14.0                   1.661    L
#
#       faculty_count
# 1910          3.065
# 1911          4.725
# 1912          4.646
# 1913        968.000
# 1914          6.708
# ...             ...
# 2903          1.331
# 2904        686.000
# 2905        707.000
# 2906          2.081
# 2907          1.478
#
# [992 rows x 11 columns]

# %% [markdown]
# ## Преобразование категориальных признаков в числовые

# %% [markdown]
# Приведем пример LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df['research_output'].unique()
# Out:
# array(['Very High', 'Very high', 'High', 'Medium', 'Low'], dtype=object)

# %%
df['research_output'] = df['research_output'].str.replace('h', 'H')

# %%
df['research_output'].unique()
# Out:
# array(['Very HigH', 'HigH', 'Medium', 'Low'], dtype=object)

# %%
le = LabelEncoder()
df['research_output'] = le.fit_transform(df['research_output'])

# %%
le.classes_
# Out:
# array(['HigH', 'Low', 'Medium', 'Very HigH'], dtype=object)

# %%
df['research_output']
# Out:
# 1910    3
# 1911    3
# 1912    3
# 1913    3
# 1914    3
#        ..
# 2903    0
# 2904    3
# 2905    0
# 2906    3
# 2907    0
# Name: research_output, Length: 992, dtype: int32
