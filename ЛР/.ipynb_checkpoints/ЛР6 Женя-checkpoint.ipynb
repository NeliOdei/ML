# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'C:\Users\rocki\Downloads\climate_data.csv', header=0, index_col=0, parse_dates=True,
squeeze=True)
df = df.replace(',', '.', regex=True)

# %% [markdown]
# ## Первичная обработка данных и визуализация

# %% [markdown]
# ### Первичный анализ

# %% [markdown]
# Выведем первые 5 строк датасета:

# %%
df.head()
# Out:
#               Tn    Tx  Tavg  RH_avg    RR   ss  ff_x  ddd_x  ff_avg ddd_car  \
# date
# 2010-01-01  21.4  30.2  27.1    82.0   9.0  0.5   7.0   90.0     5.0      E
# 2010-02-01  21.0  29.6  25.7    95.0  24.0  0.2   6.0   90.0     4.0      E
# 2010-03-01  20.2  26.8  24.5    98.0  63.0  0.0   5.0   90.0     4.0      E
# 2010-04-01  21.0  29.2  25.8    90.0   0.0  0.1   4.0  225.0     3.0      SW
# 2010-05-01  21.2  30.0  26.7    90.0   2.0  0.4   NaN    NaN     NaN     NaN
#
#             station_id
# date
# 2010-01-01       96001
# 2010-02-01       96001
# 2010-03-01       96001
# 2010-04-01       96001
# 2010-05-01       96001

# %% [markdown]
# Определим размер датасета:

# %%
df.shape
# Out:
# (589265, 11)

# %%
df = df.head(700)

# %% [markdown]
# Определим типы данных:

# %%
df.dtypes
# Out:
# Tn            float64
# Tx            float64
# Tavg          float64
# RH_avg        float64
# RR            float64
# ss            float64
# ff_x          float64
# ddd_x         float64
# ff_avg        float64
# ddd_car        object
# station_id      int64
# dtype: object

# %% [markdown]
# ### Обработка данных

# %%
def draw_missing(df):
    total = df.isnull().sum().sort_values(ascending=False)
    percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)*100
    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    return missing_data

# %%
draw_missing(df).round(1)
# Out:
#             Total  Percent
# ff_x           93     13.3
# ddd_x          93     13.3
# ff_avg         93     13.3
# ddd_car        93     13.3
# RR              1      0.1
# Tn              0      0.0
# Tx              0      0.0
# Tavg            0      0.0
# RH_avg          0      0.0
# ss              0      0.0
# station_id      0      0.0

# %%
df = df.dropna()

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler, Normalizer

# %%
sc1 = MinMaxScaler()
df['RH_avg'] = sc1.fit_transform(df[['RH_avg']])

# %%
df
# Out:
#               Tn    Tx  Tavg    RH_avg    RR   ss  ff_x  ddd_x  ff_avg  \
# date
# 2010-01-01  21.4  30.2  27.1  0.448276   9.0  0.5   7.0   90.0     5.0
# 2010-02-01  21.0  29.6  25.7  0.896552  24.0  0.2   6.0   90.0     4.0
# 2010-03-01  20.2  26.8  24.5  1.000000  63.0  0.0   5.0   90.0     4.0
# 2010-04-01  21.0  29.2  25.8  0.724138   0.0  0.1   4.0  225.0     3.0
# 2010-08-01  21.8  29.8  26.8  0.758621   3.0  0.6   5.0   90.0     4.0
# ...          ...   ...   ...       ...   ...  ...   ...    ...     ...
# 2011-11-27  18.8  26.2  24.5  0.896552  47.0  0.0   7.0  225.0     5.0
# 2011-11-28  19.0  30.6  27.1  0.655172   0.0  0.5   5.0  135.0     5.0
# 2011-11-29  19.8  30.2  25.2  0.758621   9.0  0.0   5.0   90.0     4.0
# 2011-11-30  18.4  30.0  26.7  0.655172  23.0  0.3   7.0   90.0     5.0
# 2011-01-12  18.0  28.8  25.3  0.689655   4.0  0.0   4.0  135.0     3.0
#
#            ddd_car  station_id
# date
# 2010-01-01      E        96001
# 2010-02-01      E        96001
# 2010-03-01      E        96001
# 2010-04-01      SW       96001
# 2010-08-01      E        96001
# ...            ...         ...
# 2011-11-27      SW       96001
# 2011-11-28      SE       96001
# 2011-11-29      E        96001
# 2011-11-30      E        96001
# 2011-01-12      SW       96001
#
# [606 rows x 11 columns]

# %%
df = df.drop(columns=['Tn'], axis=1)
df = df.drop(columns=['Tx'], axis=1)
df = df.drop(columns=['Tavg'], axis=1)
df = df.drop(columns=['RR'], axis=1)
df = df.drop(columns=['ss'], axis=1)
df = df.drop(columns=['ff_x'], axis=1)
df = df.drop(columns=['ddd_x'], axis=1)
df = df.drop(columns=['ff_avg'], axis=1)
df = df.drop(columns=['ddd_car'], axis=1)
df = df.drop(columns=['station_id'], axis=1)

# %% [markdown]
# ### Основные статистические характеристки

# %%
df.describe()
# Out:
#            RH_avg
# count  606.000000
# mean     0.588767
# std      0.182787
# min      0.000000
# 25%      0.456897
# 50%      0.620690
# 75%      0.724138
# max      1.000000

# %% [markdown]
# ### Визуализация исходного временного ряда

# %%
fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(10,5))
fig.suptitle('Временной ряд в виде графика')
df.plot(ax=ax, legend=False)
pyplot.show()

# %%
fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(10,5))
fig.suptitle('Первые 30 точек ряда')
df[:30].plot(ax=ax, legend=False)
pyplot.show()

# %%
fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(10,5))
fig.suptitle('Гистограмма')
df.hist(ax=ax, legend=False)
pyplot.show()

# %%
fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(10,5))
fig.suptitle('Плотность вероятности распределения данных')
df.plot(ax=ax, kind='kde', legend=False)
pyplot.show()

# %%
for i in range(1, 5):
    fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(5,4))
    fig.suptitle(f'Лаг порядка {i}')
    pd.plotting.lag_plot(df, lag=i, ax=ax)
    pyplot.show()

# %% [markdown]
# Наблюдается достаточно сильная положительная корреляция.

# %% [markdown]
# Автокорреляционная диаграмма:

# %%
fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(10,5))
fig.suptitle('Автокорреляционная диаграмма')
pd.plotting.autocorrelation_plot(df, ax=ax)
pyplot.show()

# %% [markdown]
# Автокорреляционная функция:

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(df, lags=30)
plt.tight_layout()

# %% [markdown]
# Частичная автокорреляционная функция:

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(df, lags=30)
plt.tight_layout()

# %% [markdown]
# Временной ряд со скользящими средними:

# %%
df2 = df.copy()

# %%
df2['SMA_10'] = df2['RH_avg'].rolling(10, min_periods=1).mean()
df2['SMA_20'] = df2['RH_avg'].rolling(20, min_periods=1).mean()

# %%
fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(10,5))
fig.suptitle('Временной ряд со скользящими средними')
df2[:100].plot(ax=ax, legend=True)
pyplot.show()

# %% [markdown]
# ## Прогнозирование временного ряда с использованием авторегрессионного метода

# %% [markdown]
# Будем использовать авторегриссионный метод ARIMA:

# %%
from statsmodels.tsa.arima.model import ARIMA

# %% [markdown]
# Разделение выборки на обучающую и тестовую

# %%
xnum = list(range(df2.shape[0]))
Y = df2['RH_avg'].values
train_size = int(len(Y) * 0.7)
xnum_train, xnum_test = xnum[0:train_size], xnum[train_size:]
train, test = Y[0:train_size], Y[train_size:]
history_arima = [x for x in train]

# %% [markdown]
# ## Прогноз ARIMA

# %%
arima_order = (6, 1, 0)
predictions_arima = list()
for t in range(len(test)):
    model_arima = ARIMA(history_arima, order=arima_order)
    model_arima_fit = model_arima.fit()
    yhat_arima = model_arima_fit.forecast()[0]
    predictions_arima.append(yhat_arima)
    history_arima.append(test[t])
# Out:
# C:\Users\rocki\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\rocki\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
df2['predictions_ARIMA'] = (train_size * [np.NAN]) + list(predictions_arima)

# %%
fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(20,10))
fig.suptitle('Предсказания временного ряда')
df2.plot(ax=ax, legend=True)
pyplot.show()

# %%
fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(20,10))
fig.suptitle('Предсказания временного ряда (тестовая выборка)')
df2[train_size:].plot(ax=ax, legend=True)
pyplot.show()

# %% [markdown]
# Предсказания ARIMA точны, близки к исходному, далеки от среднего скользящего.

# %% [markdown]
# ## Метрики

# %% [markdown]
# MAE и MSE:

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mean_squared_error(test, predictions_arima, squared=False)
# Out:
# 0.19557754586446832

# %%
mean_absolute_error(test, predictions_arima)
# Out:
# 0.15466487449017421

# %% [markdown]
# ## Прогнозирование временного ряда с использованием метода символьной регрессии

# %% [markdown]
# Будем использовать библиотеку gplearn:

# %%
# pip install gplearn

# %%
from gplearn.genetic import SymbolicRegressor

# %%
function_set = ['add', 'sub', 'mul', 'div', 'sin']
est_gp = SymbolicRegressor(population_size=500, metric='mse',
                               generations=200, stopping_criteria=0.01,
                               init_depth=(4, 10), verbose=1, function_set=function_set,
                               const_range=(-10, 10), random_state=0)

# %%
est_gp.fit(np.array(xnum_train).reshape(-1, 1), train.reshape(-1, 1))
# Out:
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0   263.65      1.10502e+58       14        0.0222388              N/A      7.36m
#    1    74.10      1.72644e+14       14        0.0222388              N/A      1.96m
#    2    26.53      1.28613e+07        9        0.0222239              N/A      1.08m
#    3    11.46          119.322        9        0.0222239              N/A      1.47m
#    4     6.50          355.966        8        0.0222209              N/A     55.66s
#    5     5.69        0.0540701        5        0.0222178              N/A     52.79s
#    6     5.31          119.872        5        0.0222178              N/A      1.20m
#    7     4.93         0.176763        5        0.0222178              N/A     51.89s
#    8     4.84         0.100726        5        0.0222178              N/A     56.16s
#    9     4.85        0.0339113        5        0.0222178              N/A     58.89s
#   10     5.38           305729        5        0.0222178              N/A      1.11m
#   11     5.23        0.0378732        5        0.0222178              N/A      1.04m
#   12     5.05         0.033541        5        0.0222178              N/A      1.25m
#   13     4.95      1.29331e+07        5        0.0222178              N/A      1.31m
#   14     4.99          830.525        5        0.0222178              N/A      1.07m
#   15     4.97          119.876        5        0.0222178              N/A      1.24m
#   16     5.07         0.231699        5        0.0222178              N/A     56.15s
#   17     4.98          620.386        5        0.0222178              N/A      1.19m
#   18     5.15          476.655        5        0.0222178              N/A      1.23m
#   19     5.03        0.0382217        5        0.0222178              N/A      1.01m
#   20     5.16      1.28515e+07        5        0.0222178              N/A      1.32m
#   21     5.14           8.4345        5        0.0222178              N/A     51.90s
#   22     5.08          476.654        5        0.0222178              N/A      1.23m
#   23     5.01      6.46827e+06        5        0.0222178              N/A      1.11m
#  171     2.97          989.506        3        0.0222218              N/A     11.83s
#  172     3.08       1.2851e+07        3        0.0222218              N/A      8.66s
#  173     3.10      9.43644e+14        3        0.0222218              N/A      8.58s
#  174     3.07      2.59037e+07        3        0.0222218              N/A     10.53s
#  175     3.03          145.232        3        0.0222218              N/A      7.85s
#  176     2.90      1.31768e+07        3        0.0222218              N/A     11.90s
#  177     3.03          42736.4        3        0.0222218              N/A      6.65s
#  178     2.96          721.672        3        0.0222218              N/A      6.55s
#  179     3.11          65210.4        3        0.0222218              N/A     10.53s
#  180     3.10          19524.2        3        0.0222218              N/A      7.54s
#  181     3.14          845.225        3        0.0222218              N/A      9.36s
#  182     3.03      3.52341e+08        3        0.0222218              N/A      6.86s
#  183     3.00          17388.7        3        0.0222218              N/A      6.41s
#  184     3.10          11347.9        3        0.0222218              N/A      6.47s
#  185     3.03      1.28517e+07        3        0.0222218              N/A      5.06s
#  186     2.97          3.66122        3        0.0222218              N/A      4.77s
#  187     3.02          233.725        3        0.0222218              N/A      3.61s
#  188     3.03      1.30435e+12        3        0.0222218              N/A      4.25s
#  189     2.99          2700.61        3        0.0222218              N/A      3.12s
#  190     2.97          1449.24        3        0.0222218              N/A      3.60s
#  191     3.08      2.57151e+07        3        0.0222218              N/A      3.08s
#  192     3.23      2.73433e+07        3        0.0222218              N/A      2.47s
#  193     2.99          10738.3        3        0.0222218              N/A      2.11s
#  194     3.09          127.829        3        0.0222218              N/A      1.73s
#  195     3.27      2.63425e+31        3        0.0222218              N/A      2.02s
#  196     3.13          4651.48        3        0.0222218              N/A      1.06s
#  197     3.04      1.95751e+10        3        0.0222218              N/A      0.80s
#  198     2.92          481.835        3        0.0222218              N/A      0.40s
#  199     2.95           30.358        3        0.0222218              N/A      0.00s
# SymbolicRegressor(const_range=(-10, 10),
#                   function_set=['add', 'sub', 'mul', 'div', 'sin'],
#                   generations=200, init_depth=(4, 10), metric='mse',
#                   population_size=500, random_state=0, stopping_criteria=0.01,
#                   verbose=1)

# %%
y_gp = est_gp.predict(np.array(xnum_test).reshape(-1, 1))
y_gp[:10]
# Out:
# array([0.63384749, 0.63384749, 0.63384749, 0.63384749, 0.63384749,
#        0.63384749, 0.63384749, 0.63384749, 0.63384749, 0.63384749])

# %%
df2['predictions_GPLEARN'] = (train_size * [np.NAN]) + list(y_gp)

# %% [markdown]
# ## Визуализация

# %% [markdown]
# Построим дерево по символьной регрессии:

# %%
import graphviz
import pydotplus
from sklearn.tree import export_graphviz

# %%
dot_data = est_gp._program.export_graphviz()
graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# Построим график по тестовой выборке:

# %%
fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(20,10))
fig.suptitle('Предсказания временного ряда (тестовая выборка)')
df2[train_size:].plot(ax=ax, legend=True)
pyplot.show()

# %% [markdown]
# ## Метрики

# %% [markdown]
# MAE и MSE:

# %%
mean_squared_error(test, y_gp, squared=False)
# Out:
# 0.25702320870414386

# %%
mean_absolute_error(test, y_gp)
# Out:
# 0.20628325543131054
